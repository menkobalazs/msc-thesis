# %% [markdown]
# # [Uncalled4](https://www.nature.com/articles/s41592-025-02631-4); [GitHub](https://github.com/skovaka/uncalled4)

# %%
# %%bash
# uncalled4=/v/o67ut7/.local/bin/uncalled4
# $uncalled4 -h
# Out:
# usage: uncalled4 [subcommand] [-h] [-v]
#
# Utility for Nanopore Current ALignment to Large Expanses of DNA
#
# subcommand options:
# Signal Alignment:
#   align      Perform DTW alignment guided by basecalled alignments
#   train      Train new k-mer pore models
#   convert    Convert between signal alignment file formats
#
# Analysis:
#   refstats   Calculate per-reference-coordinate statistics
#   readstats  Compute per-read summary statistics
#   compare    Compare multiple alignments of the same read
#
# Visualization:
#   dotplot    Plot signal-to-reference alignment dotplots
#   trackplot  Plot alignment tracks and per-reference statistics
#   browser    Interactive signal alignment genome browser
#
# options:
#   -h, --help     show this help message and exit
#   -v, --version  show program's version number and exit

# %%
# %%bash
# FAST5='/v/projects/nanopore/agnes/signal_visualization/data/timin0421/workspace/'
# REF="/v/volumes/nanopore/ref/p300_ID3.fasta"
# BAM='/v/projects/nanopore/agnes/signal_visualization/data/timin0421/pass/bam_runid_db4f2d165a2cb95d870762f8bd1749edb5a64d5d_0_0.bam'
# OUT_NAME='/v/projects/nanopore/balazs/data/uncalled_data/'
#
# uncalled4=/v/o67ut7/.local/bin/uncalled4
# $uncalled4 align -h
# Out:
# usage: uncalled4 align [-h] [--ref REF | --self] [--reads READS [READS ...]]
#                        --bam-in [BAM_IN] [-p PROCESSES] [--flowcell FLOWCELL]
#                        [--kit KIT] [--basecaller-profile BASECALLER_PROFILE]
#                        [--rna] [--ordered-out] [-f] [--kmer-shift KMER_SHIFT]
#                        [--bam-chunksize BAM_CHUNKSIZE] [--out-name OUT_NAME]
#                        [-r] [-l READ_FILTER] [-x READ_INDEX] [-n MAX_READS]
#                        [--count-events] [--del-max DEL_MAX]
#                        [--ins-max INS_MAX] [--unmask-splice] [--method METHOD]
#                        [-c {abs_diff,z_score,norm_pdf}] [-b BAND_WIDTH]
#                        [-s BAND_SHIFT] [--mvcmp-mask MVCMP_MASK]
#                        [--max-norm-dist MAX_NORM_DIST] [--max-sd MAX_SD]
#                        [--min-aln-length MIN_ALN_LENGTH]
#                        [-N {ref_mom,model_mom}] [--zero-ts] [-C CONFIG]
# ...

# %%
# %%bash
# FAST5='/v/projects/nanopore/agnes/signal_visualization/data/timin0421/workspace/'
# REF="/v/volumes/nanopore/ref/p300_ID3.fasta"
# BAM='/v/projects/nanopore/agnes/signal_visualization/data/timin0421/pass/basecalls.bam'
# OUT_PATH='/v/projects/nanopore/balazs/data/uncalled_data/'
#
# uncalled4=/v/o67ut7/.local/bin/uncalled4
# $uncalled4 align --ref $REF --reads $FAST5  --bam-in $BAM -r  --tsv-out $OUT_PATH/out.tsv
# Out:
# Loading read index '/v/projects/nanopore/agnes/signal_visualization/data/timin0421/workspace/read_index.txt'
# Auto-detected flowcell='FLO-FLG001' kit='SQK-LSK110'
# Using model 'dna_r9.4.1_400bps_6mer'
# Counter()

# %%
# %%bash
# uncalled4=/v/o67ut7/.local/bin/uncalled4
# $uncalled4 align -h
# Out:
# usage: uncalled4 align [-h] [--ref REF | --self] [--reads READS [READS ...]]
#                        --bam-in [BAM_IN] [-p PROCESSES] [--flowcell FLOWCELL]
#                        [--kit KIT] [--basecaller-profile BASECALLER_PROFILE]
#                        [--rna] [--ordered-out] [-f] [--kmer-shift KMER_SHIFT]
#                        [--bam-chunksize BAM_CHUNKSIZE] [--out-name OUT_NAME]
#                        [-r] [-l READ_FILTER] [-x READ_INDEX] [-n MAX_READS]
#                        [--count-events] [--del-max DEL_MAX]
#                        [--ins-max INS_MAX] [--unmask-splice] [--method METHOD]
#                        [-c {abs_diff,z_score,norm_pdf}] [-b BAND_WIDTH]
#                        [-s BAND_SHIFT] [--mvcmp-mask MVCMP_MASK]
#                        [--max-norm-dist MAX_NORM_DIST] [--max-sd MAX_SD]
#                        [--min-aln-length MIN_ALN_LENGTH]
#                        [-N {ref_mom,model_mom}] [--zero-ts] [-C CONFIG]
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('/v/projects/nanopore/balazs/data/uncalled_data/out.tsv')
df.head()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df = pd.read_csv('/v/projects/nanopore/balazs/data/uncalled_data/out.tsv')
#       2 df.head()
#
# File /opt/conda/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
